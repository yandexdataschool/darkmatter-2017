# %%
import seaborn
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Line3DCollection
from matplotlib import pylab as plt
import root_numpy
import pandas as pd


BRICK_X = 124000
BRICK_Y = 99000
BRICK_Z = 75000
SAFE_M = 10000

# %%
root_numpy.list_branches("mcdata_taue2.root", treename="Data")
# Out:
# ['Event_id',
#  'Neutrino_Energy',
#  'Brick_coordinate',
#  'PDG_codes_all_particles_at_primary_vtx',
#  'PDG_codes_all_particles_at_secondary_vtx',
#  'shortorlong',
#  'Decay_length_true',
#  'Primary_vertex_X_position',
#  'Primary_vertex_Y_position',
#  'Primary_vertex_Z_position',
#  'Secondary_vertex_X_position',
#  'Secondary_vertex_Y_position',
#  'Secondary_vertex_Z_position',
#  'parent_px',
#  'parent_py',
#  'parent_pz',
#  'ele_x',
#  'ele_y',
#  'ele_z',
#  'ele_sx',
#  'ele_sy',
#  'ele_px',
#  'ele_py',
#  'ele_pz',
#  'ele_P',
#  'TOP_X',
#  'TOP_Y',
#  'TOP_Z',
#  'TOP_SX',
#  'TOP_SY',
#  'TOP_P',
#  'BOT_X',
#  'BOT_Y',
#  'BOT_Z',
#  'BOT_SX',
#  'BOT_SY',
#  'BOT_P',
#  'Ntot_BT',
#  'BT_X',
#  'BT_Y',
#  'BT_Z',
#  'BT_SX',
#  'BT_SY',
#  'BT_plate',
#  'BT_P',
#  'chisquare',
#  'alfa',
#  'deltaSx',
#  'deltaSy']

# %%
def load_mc(filename="mcdata_taue2.root", step=1):
    mc = root_numpy.root2array(
                        filename,
                        treename="Data",
                        branches=["Event_id", "ele_P",
                                   "BT_X", "BT_Y", "BT_Z",
                                   "BT_SX", "BT_SY", "BT_plate",
                                   "ele_x", "ele_y", "ele_z", 
                                   "ele_sx", "ele_sy", 
                                   "chisquare", "alfa", "deltaSx", "deltaSy"],
                        step=step)
    pmc = pd.DataFrame(mc)
    pmc['numtracks'] = pmc.BT_X.apply(lambda x: len(x))
    # cuts
    shapechange = [pmc.shape[0]]
    pmc = pmc[pmc.ele_P > 0.1]
    shapechange.append(pmc.shape[0])
    pmc = pmc[pmc.ele_x.abs() < BRICK_X / 2 - SAFE_M]
    shapechange.append(pmc.shape[0])
    pmc = pmc[pmc.ele_y.abs() < BRICK_Y / 2 - SAFE_M]
    shapechange.append(pmc.shape[0])
    pmc = pmc[pmc.ele_z < 0]
    shapechange.append(pmc.shape[0])
    pmc = pmc[pmc.numtracks > 3]
    shapechange.append(pmc.shape[0])
    print ("numtracks reduction by cuts: ", shapechange)
    # calc centers
    # to brick reference frame and center
#     pmc['m_BT_X'] = pmc.BT_X.apply(lambda x: x.mean())
#     pmc['m_BT_Y'] = pmc.BT_Y.apply(lambda x: x.mean())
#     pmc['m_BT_Z'] = pmc.BT_Z.apply(lambda x: x.mean())
    pmc.BT_X += BRICK_X / 2
    pmc.BT_Y += BRICK_Y / 2
    pmc.BT_Z += BRICK_Z / 2
    pmc.ele_x += BRICK_X / 2
    pmc.ele_y += BRICK_Y / 2
    pmc.ele_z += BRICK_Z / 2
    #print "len(pmc): {len}".format(len=len(pmc))
    
    # Correct Z coordinate to match plates coordinates
    pmc.BT_Z = (pmc.BT_plate - 1) * 1293
    
    return pmc

# %%
df = load_mc()
# Out:
# ('numtracks reduction by cuts: ', [18724, 18679, 15471, 12215, 6271, 6001])

# %%
df.BT_Z.apply(lambda x: min(x)).min()
# Out:
# 432.875

# %%
df.BT_Z + ((df.BT_plate -1) * 1293 - df.BT_Z)
# Out:
# 0        [10344.0, 10344.0, 10344.0, 11637.0, 11637.0, ...
# 7        [38790.0, 38790.0, 40083.0, 40083.0, 40083.0, ...
# 8        [12930.0, 14223.0, 15516.0, 16809.0, 18102.0, ...
# 10       [31032.0, 32325.0, 32325.0, 33618.0, 33618.0, ...
# 11       [34911.0, 36204.0, 37497.0, 38790.0, 38790.0, ...
# 13       [14223.0, 15516.0, 16809.0, 18102.0, 19395.0, ...
# 14       [14223.0, 15516.0, 16809.0, 18102.0, 36204.0, ...
# 17       [9051.0, 10344.0, 11637.0, 12930.0, 14223.0, 1...
# 35       [31032.0, 32325.0, 33618.0, 34911.0, 36204.0, ...
# 42       [32325.0, 33618.0, 33618.0, 34911.0, 34911.0, ...
# 53       [6465.0, 7758.0, 7758.0, 7758.0, 9051.0, 9051....
# 54       [1293.0, 2586.0, 3879.0, 5172.0, 6465.0, 6465....
# 55       [27153.0, 28446.0, 29739.0, 29739.0, 29739.0, ...
# 58       [27153.0, 28446.0, 29739.0, 29739.0, 29739.0, ...
# 61       [25860.0, 27153.0, 28446.0, 29739.0, 31032.0, ...
# 64       [9051.0, 10344.0, 11637.0, 12930.0, 14223.0, 1...
# 65       [18102.0, 19395.0, 20688.0, 21981.0, 21981.0, ...
# 69       [21981.0, 23274.0, 24567.0, 25860.0, 27153.0, ...
# 73       [15516.0, 16809.0, 18102.0, 19395.0, 20688.0, ...
# 77       [7758.0, 9051.0, 10344.0, 11637.0, 11637.0, 11...
# 78       [10344.0, 11637.0, 12930.0, 14223.0, 15516.0, ...
# 80       [21981.0, 21981.0, 21981.0, 23274.0, 23274.0, ...
# 84       [20688.0, 21981.0, 23274.0, 24567.0, 24567.0, ...
# 85       [2586.0, 3879.0, 5172.0, 5172.0, 6465.0, 7758....
# 87       [23274.0, 24567.0, 25860.0, 27153.0, 28446.0, ...
# 89       [14223.0, 15516.0, 16809.0, 18102.0, 19395.0, ...
# 90       [12930.0, 14223.0, 15516.0, 16809.0, 18102.0, ...
# 93       [12930.0, 14223.0, 14223.0, 14223.0, 15516.0, ...
# 94       [20688.0, 21981.0, 23274.0, 24567.0, 24567.0, ...
# 99       [10344.0, 11637.0, 12930.0, 14223.0, 15516.0, ...
#                                ...
# 18642    [3879.0, 5172.0, 6465.0, 6465.0, 6465.0, 7758....
# 18643    [31032.0, 32325.0, 33618.0, 33618.0, 33618.0, ...
# 18646    [20688.0, 21981.0, 23274.0, 24567.0, 25860.0, ...
# 18648    [12930.0, 14223.0, 15516.0, 16809.0, 16809.0, ...
# 18649    [36204.0, 37497.0, 38790.0, 40083.0, 41376.0, ...
# 18651    [5172.0, 6465.0, 7758.0, 9051.0, 9051.0, 10344...
# 18653    [27153.0, 27153.0, 28446.0, 28446.0, 29739.0, ...
# 18657    [36204.0, 37497.0, 38790.0, 40083.0, 40083.0, ...
# 18659    [2586.0, 3879.0, 5172.0, 5172.0, 5172.0, 6465....
# 18662    [34911.0, 36204.0, 37497.0, 38790.0, 40083.0, ...
# 18664    [27153.0, 28446.0, 29739.0, 31032.0, 32325.0, ...
# 18667    [18102.0, 19395.0, 19395.0, 19395.0, 20688.0, ...
# 18668    [33618.0, 34911.0, 36204.0, 37497.0, 37497.0, ...
# 18669    [36204.0, 37497.0, 37497.0, 37497.0, 38790.0, ...
# 18672    [15516.0, 16809.0, 18102.0, 19395.0, 20688.0, ...
# 18674    [10344.0, 11637.0, 12930.0, 14223.0, 15516.0, ...
# 18675    [6465.0, 7758.0, 9051.0, 10344.0, 11637.0, 116...
# 18676    [29739.0, 31032.0, 32325.0, 33618.0, 34911.0, ...
# 18680    [2586.0, 3879.0, 5172.0, 6465.0, 7758.0, 7758....
# 18688    [6465.0, 7758.0, 9051.0, 10344.0, 10344.0, 103...
# 18694    [32325.0, 33618.0, 33618.0, 34911.0, 36204.0, ...
# 18695    [24567.0, 25860.0, 27153.0, 28446.0, 28446.0, ...
# 18701    [15516.0, 16809.0, 18102.0, 19395.0, 20688.0, ...
# 18705    [16809.0, 18102.0, 19395.0, 20688.0, 21981.0, ...
# 18711    [10344.0, 11637.0, 12930.0, 12930.0, 12930.0, ...
# 18714    [34911.0, 36204.0, 37497.0, 38790.0, 40083.0, ...
# 18715    [15516.0, 23274.0, 23274.0, 23274.0, 23274.0, ...
# 18720    [12930.0, 14223.0, 14223.0, 14223.0, 15516.0, ...
# 18721    [28446.0, 29739.0, 29739.0, 29739.0, 31032.0, ...
# 18722    [21981.0, 23274.0, 23274.0, 23274.0, 24567.0, ...
# dtype: object

# %%
df.BT_plate.iloc[4].min()

# %%
def plot_ith_quiver(mc, id=0):
    z = mc[id]
    dZ = 30
    U = z["BT_SX"] * dZ
    V = z["BT_SY"] * dZ
    W = dZ
    fig = plt.figure(figsize=(10,6))
    ax = fig.gca(projection='3d')
    _ = ax.quiver(z["BT_X"], z["BT_Y"], z["BT_Z"], U, V, W, length=100)
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    print ("electron momentum: {p:.2f}, len(slopes): {slopes}".format(p=z['ele_P'], slopes=len(U)))

# %%
def plot_mc(mcdf, id=0):
    dZ = 205
    df = mcdf.ix[id]
    # mind the order!
    d0 = pd.DataFrame([
                df['BT_Z'],
                df['BT_X'],
                df['BT_Y']],
                index=['z', 'x', 'y']).T
    numtracks = d0.shape[0]
    dd = pd.DataFrame([
            df['BT_SX']*dZ,
            df['BT_SY']*dZ],
            index=['x', 'y']).T
    dd.insert(loc=0, column='z', value=dZ)
    d1 = d0 + dd
    # print d0, d1
    C = plt.cm.Reds(0.5)
    lc = Line3DCollection(list(zip(d0.values, d1.values)), colors=C, alpha=0.9, lw=2)

    fig = plt.figure(figsize=(12,8))
    ax = fig.gca(projection='3d')
    ax.view_init(azim=-103, elev=16)
    ax.add_collection3d(lc)
    
    # mind the order!
    ax.set_xlabel("z")
    ax.set_ylabel("x")
    ax.set_zlabel("y")  
    ax.set_xlim(d0['z'].min(), d0['z'].max())
    ax.set_ylim(d0['x'].min(), d0['x'].max())
    ax.set_zlim(d0['y'].min(), d0['y'].max())
    print ("len(slopes): {slopes}".format(slopes=numtracks))

# %%
# %matplotlib inline
# mc = load_mc(step=100)
# plot_mc(mc, id=0)
# Out:
# numtracks reduction by cuts:  [188, 186, 143, 112, 48, 47]
# len(slopes): 3664

# %%
def meta_mc_analyse(mc):
    #_ = plt.hist(mc['ele_P'], bins=100, range=[0, 5])
    lens = map(lambda x: len(x[1].BT_X), mc.iterrows())
    _ = plt.hist(lens, bins=100, range=(0,20))
    p = pd.DataFrame(lens)
    #print p
    print (p[p[0] < 3])

# %%
# meta_mc_analyse(load_mc())
# Out:
# numtracks reduction by cuts:  [18724, 18679, 15471, 12215, 6271, 6001]
# Empty DataFrame
# Columns: [0]
# Index: []
